# %% [markdown]
# # AWSCTD Training on Google Colab GPU
# Тренінг моделей на GPU з використанням embedding та one-hot encoding

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
!git clone https://github.com/nikitkah1love/mastercnn.git

#!cd mastercnn/Python; python Python/AWSCTD_embedding.py ../drive/MyDrive/MalAPI2019/train_windowed_w800_s200.csv ../drive/MyDrive/MalAPI2019/test_windowed_w800_s200.csv AWSCTD-CNN-S-EMBEDDING
!cd mastercnn/Python; python AWSCTD.py ../../drive/MyDrive/MalAPI2019/dataset_n10.csv AWSCTD-CNN-S

# %%
!cd mastercnn/Python; python AWSCTD.py ../../drive/MyDrive/MalAPI2019/dataset_n20.csv AWSCTD-CNN-S

# %%
!cd mastercnn/Python; python AWSCTD.py ../../drive/MyDrive/MalAPI2019/dataset_n40.csv AWSCTD-CNN-S

# %%
!cd mastercnn/Python; python AWSCTD.py ../../drive/MyDrive/MalAPI2019/dataset_n80.csv AWSCTD-CNN-S

# %%
!cd mastercnn/Python; python AWSCTD.py ../../drive/MyDrive/MalAPI2019/dataset_n100.csv AWSCTD-CNN-S

# %%
!cd mastercnn/Python; python AWSCTD.py ../../drive/MyDrive/MalAPI2019/dataset_n200.csv AWSCTD-CNN-S

# %%
!cd mastercnn/Python; python AWSCTD.py ../../drive/MyDrive/MalAPI2019/dataset_n400.csv AWSCTD-CNN-S

# %%
!cd mastercnn/Python; python AWSCTD.py ../../drive/MyDrive/MalAPI2019/dataset_n600.csv AWSCTD-CNN-S

# %%
!cd mastercnn/Python; python AWSCTD.py ../../drive/MyDrive/MalAPI2019/dataset_n800.csv AWSCTD-CNN-S

# %%
!cd mastercnn/Python; python AWSCTD.py ../../drive/MyDrive/MalAPI2019/dataset_n1000.csv AWSCTD-CNN-S

# %% [markdown]
# ## Embedding тренінг

# %%
!cd mastercnn/Python; python AWSCTD_embedding_kfold.py ../../drive/MyDrive/MalAPI2019/dataset_n10.csv AWSCTD-CNN-S-EMBEDDING

# %%
!cd mastercnn/Python; python AWSCTD_embedding_kfold.py ../../drive/MyDrive/MalAPI2019/dataset_n20.csv AWSCTD-CNN-S-EMBEDDING

# %%
!cd mastercnn/Python; python AWSCTD_embedding_kfold.py ../../drive/MyDrive/MalAPI2019/dataset_n40.csv AWSCTD-CNN-S-EMBEDDING

# %%
!cd mastercnn/Python; python AWSCTD_embedding_kfold.py ../../drive/MyDrive/MalAPI2019/dataset_n80.csv AWSCTD-CNN-S-EMBEDDING

# %%
!cd mastercnn/Python; python AWSCTD_embedding_kfold.py ../../drive/MyDrive/MalAPI2019/dataset_n100.csv AWSCTD-CNN-S-EMBEDDING

# %%
!cd mastercnn/Python; python AWSCTD_embedding_kfold.py ../../drive/MyDrive/MalAPI2019/dataset_n200.csv AWSCTD-CNN-S-EMBEDDING

# %%
!cd mastercnn/Python; python AWSCTD_embedding_kfold.py ../../drive/MyDrive/MalAPI2019/dataset_n400.csv AWSCTD-CNN-S-EMBEDDING

# %%
!cd mastercnn/Python; python AWSCTD_embedding_kfold.py ../../drive/MyDrive/MalAPI2019/dataset_n600.csv AWSCTD-CNN-S-EMBEDDING

# %%
!cd mastercnn/Python; python AWSCTD_embedding_kfold.py ../../drive/MyDrive/MalAPI2019/dataset_n800.csv AWSCTD-CNN-S-EMBEDDING

# %%
!cd mastercnn/Python; python AWSCTD_embedding_kfold.py ../../drive/MyDrive/MalAPI2019/dataset_n1000.csv AWSCTD-CNN-S-EMBEDDING

# %%
!cp mastercnn/Python/Python/CM/* drive/MyDrive/MalAPI2019/alltheresults
!cp mastercnn/Python/Python/Metrics/* drive/MyDrive/MalAPI2019/alltheresults

# %% [markdown]
# ## One-hot тренінг

# %%
# 6a. One-hot: no_repeats_first_n
!python Python/run_noRepeats_firstN_onehot.py

# %%
# 6b. One-hot: firstN
!python Python/run_firstN_experiments_onehot.py

# %% [markdown]
# ## Embedding dimension grid search

# %%
# 7. Grid search по embedding dimensions
!python Python/run_embedding_dim_search.py

# %% [markdown]
# ## Результати

# %%
# 8. Виведення всіх результатів
import pandas as pd
import glob

for csv_file in sorted(glob.glob('Python/*results*.csv')):
    print(f'\n{"="*70}')
    print(f'📊 {csv_file}')
    print(f'{"="*70}')
    df = pd.read_csv(csv_file)
    print(df.to_string(index=False))

# %%
# 9. Завантажити результати
from google.colab import files
import glob

for f in glob.glob('Python/*results*.csv'):
    files.download(f)
for f in glob.glob('Python/CM/*.png'):
    files.download(f)
